# %%
import os
import pandas as pd
from astropy.io import fits
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS
import numpy as np
import numpy.linalg as lin

# %% [markdown]
# ## Step 1: Read in all the galaxy files:
# - convert these all to 3 giant combined data frames across the 3 data types

# %%
import pandas as pd 
import os 
import glob 

# create paths to folders
path_cwd = os.getcwd() 
path_casbah= path_cwd+'/casbah/'
path_initial= path_cwd+'/cgm2_initial/'
path_leftover= path_cwd+'/cgm2_leftover/'

#collect all files from each folder
csv_files_casbah = glob.glob(os.path.join(path_casbah, "*.csv")) 
csv_files_initial = glob.glob(os.path.join(path_initial, "*.csv")) 
csv_files_leftover = glob.glob(os.path.join(path_leftover, "*.csv")) 

# loop over the list of csv files, combine them into large DF
# start with an empty dataframe (instead of an empty list)
casbah= pd.DataFrame()
for f in csv_files_casbah: 
    # read the csv file 
    df = pd.read_csv(f)
    # add the name of the corresponding QSO to the proper column
    df['QSO']= str(f)[40:].split('_')[0]
    # Both of these methods work but concat is the newest/ proper method...
    #casbah = casbah.append(df)
    casbah = pd.concat([casbah, df])
    
cgm_initial= pd.DataFrame()
for f in csv_files_initial: 
    # read the csv file 
    df = pd.read_csv(f) 
    # add QSO name
    df['QSO']= str(f)[46:].split('_')[0]
    #cgm_initial= cgm_initial.append(df)
    cgm_initial = pd.concat([cgm_initial, df])
    
cgm_leftover= pd.DataFrame()
for f in csv_files_leftover: 
    # read the csv file 
    df = pd.read_csv(f) 
    df['QSO']= str(f)[47:].split('_')[0]
    #cgm_leftover= cgm_leftover.append(df)
    cgm_leftover = pd.concat([cgm_leftover, df])

# %%
cgm_leftover['QSO'].unique()
# Out:
# array(['J1233-0031', 'J1059+2517', 'J0935+0204', 'J2345-0059',
#        'J1555+3628', 'J0809+4619', 'J1342-0053', 'J1133+0327',
#        'J1134+2555', 'J1059+1441', 'J1016+4706', 'J1419+4207',
#        'J1553+3548', 'J1001+5944', 'J0843+4117', 'J1241+5721',
#        'J1437+5045', 'J1112+3539', 'J0943+0531', 'J1022+0132',
#        'J0914+2823'], dtype=object)

# %%
casbah['QSO'].unique()
# Out:
# array(['LBQS1435-0134', 'PG1407+265', 'FBQSJ0751+2919', 'PHL1377',
#        'PG1630+377', 'PG1522+101', 'PG1206+459'], dtype=object)

# %%
casbah.columns, cgm_initial.columns, cgm_leftover.columns
# Out:
# (Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#         'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#         'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#         'axis_ratio', 'axis_ratio_error', 'position_angle',
#         'position_angle_error', 'reduced_chi_squared', 'inclination_angle',
#         'is_good_fit', 'shows_internal_struct', 'overlaps_w_object',
#         'is_big_galaxy', 'edited', 'double_model', 'QSO'],
#        dtype='object'),
#  Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#         'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#         'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#         'axis_ratio', 'axis_ratio_error', 'position_angle',
#         'position_angle_error', 'reduced_chi_squared', 'azimuthal_angle',
#         'inclination_angle', 'is_good_fit', 'shows_internal_struct',
#         'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO',
#         'Unnamed: 0', 'Unnamed: 0.2', 'Unnamed: 0.1'],
#        dtype='object'),
#  Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#         'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#         'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#         'axis_ratio', 'axis_ratio_error', 'position_angle',
#         'position_angle_error', 'reduced_chi_squared', 'azimuthal_angle',
#         'inclination_angle', 'is_good_fit', 'shows_internal_struct',
#         'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO'],
#        dtype='object'))

# %% [markdown]
# ## For some reason there are a few NaN columns...
# - deleting those here

# %%
bad_columns= ['Unnamed: 0', 'Unnamed: 0.2', 'Unnamed: 0.1']
#del cgm_initial[]
for bad in bad_columns:
    del cgm_initial[bad]

# %%
len(cgm_initial.columns)
# Out:
# 26

# %% [markdown]
# ## Fixed!

# %%
print(len(casbah.columns)), print(len(cgm_initial.columns)), print(len(cgm_leftover.columns))
# Out:
# 25
# 26
# 26
# (None, None, None)

# %% [markdown]
# # First issue:
# - the casbah data doesnt have azimuthal data included

# %% [markdown]
# ## Step 2: find azimuthal angles for casbah...
# - thomas code from github...

# %%
#ra, dec, and redshift (ra and dec in degrees)
qso_coordz = {
    'PHL1377': [38.78077, -4.03491, 1.437],
    'FBQSJ0751+2919': [117.80128, 29.32730, 0.916],
    'PG1206+459': [182.24172, 45.67652, 1.165],
    'PG1407+265': [212.34963, 26.30587, 0.94],
    'LBQS1435-0134': [219.45118, -1.78633, 1.311],
    'PG1522+101': [231.10231, 9.97494, 1.328],
    'PG1630+377': [248.00462, 37.63055, 1.479]
}

# %% [markdown]
# # CASBAH QSO COORDS

# %%
qso_coords= pd.DataFrame(qso_coordz).transpose()
qso_coords= qso_coords.rename(columns={0: "RA", 1: "DEC", 2:"redshift"})
#qso_coords.rename(index={0: "x", 1: "y", 2: "z"})

# %%
casbah['ycoord'].describe()
# Out:
# count      92.000000
# mean     2806.287174
# std       664.035581
# min       796.770000
# 25%      2420.777500
# 50%      2815.210000
# 75%      3281.652500
# max      4102.860000
# Name: ycoord, dtype: float64

# %%
len(qso_coords)
# Out:
# 7

# %% [markdown]
# ## Need to add a column for the name of the qso in casbah

# %%
path_images= path_casbah+'images/'
# major indexing issues with casbah... this fixes a lot
#casbah= casbah.reset_index()

for image in glob.glob(os.path.join(path_images, "*")):
    hdulist = fits.open(image, memmap=True)
    hdu = hdulist[0]
    wcs = WCS(hdu.header)
    hdulist.close()
    #print(image)
    
    for index, row in qso_coords.iterrows():
        # check that it grabs the correct qso coords
        if image[47:53]== index[0:6]:
            qso_ra = qso_coords['RA'][index]
            qso_dec = qso_coords['DEC'][index]
            #print(qso_ra)

            # Converts RA/DEC of the QSO to image x/y
            coord = SkyCoord(qso_ra, qso_dec, unit='deg')
            object_pix = wcs.world_to_pixel(coord)
            qso_pix_coordx = object_pix[0]
            qso_pix_coordy = object_pix[1]

            #print(object_pix)
            #print(qso_pix_coordx)

            # Finds the changes in pixel x and y coordinates from each galaxy to the QSO
            delta_x = qso_pix_coordx - casbah['xcoord']
            delta_y = qso_pix_coordy - casbah['ycoord']
#             print("del_X",delta_x)

#             print("len_del_X",len(delta_x))
            # del_x and del_y are 2 lists of 92 values
            
            # Calculates the azimuthal angle phi for each galaxy
            phi = []
            delta_list= list(zip(delta_x,delta_y))
            #print(delta_list)
            
            for i in np.arange(0,len(delta_x),1):
                #if casbah['position_angle'][i] != 'oob':
                # Create vector a which is the vector pointing from galaxy to QSO
                #a = [delta_x[i], delta_y[i]]
                a= delta_list[i]
                #print("Vector A/0", a)
                
                # Create vectors b1 and b2 which are vectors pointing along galaxy's semi-minor axis
                # b1 and b2 are anti-parallel
                
                # finds the position angle of each galaxy in casbah table and converts it to radians
                position_angle = casbah['position_angle'][i] * (np.pi / 180)
                #print("POSANG",position_angle)
                #break

                b1 = (np.cos(position_angle), np.sin(position_angle))
                b2 = (-np.cos(position_angle), -np.sin(position_angle))
                #print("B1", b1)
                #print("B2",b2)
                
                # now sort them by QSO and finish the process using [QSO] columns i added to casbah

                # print(np.dot(a, b1))
                # Uses the relationship between the cross product of two vectors and cosine to find the angle between the two vectors
                phi_prime1 = np.arccos(np.dot(a, b1) / (lin.norm(a) * lin.norm(b1))) * (180 / np.pi)
                phi_prime2 = np.arccos(np.dot(a, b2) / (lin.norm(a) * lin.norm(b2))) * (180 / np.pi)

                # Takes the lesser of the two angles since azimuthal angle can go from 0 to +90 degrees
                if (phi_prime1 <= phi_prime2):
                    phi.append(phi_prime1)
                elif (phi_prime1 > phi_prime2):
                    phi.append(phi_prime2)
            #print(phi)
#casbah['azimuthal_angle']= phi_data
# Out:
# [54.91613618435798, 84.36290627381356, 53.11794802968511, 53.293529543246926, 86.95560537539346, 79.04937110501888, 75.49645877473947, 88.97929916488914, 45.111181121187364, 45.47798467506469, 74.60933835057754, 36.814197274652344, 82.10086361178502, 75.89514642675849, 60.08855594717831, 55.258767751207294, 56.23603143754632, 36.19550143012011, 4.259117933359723, 63.86299374702369, 9.289515374340374, 21.242420188377736, 15.690347943690234, 87.7508157235413, 63.328079226233456, 79.99944246847119, 10.763005575991807, 54.89210893776743, 1.528984512084501, 46.10580157635807, 82.05157451687018, 50.292740075303165, 31.973296865272808, 70.25726055663543, 70.67356277273046, 72.49961955919508, 2.2391119782442677, 76.36709220192239, 87.18352494763775, 78.43330864574773, 88.16506641722589, 65.95726624924488, 67.13748571153313, 13.015157763536637, 44.01773443803896, 81.02960621388532, 64.60420206190392, 73.47180758212099, 89.44793860532721, 30.55782549830672, 8.3891922166397, 45.2657670467747, 89.81396803743276, 43.0436221003942, 15.653857005478654, 12.958983886190511, 32.01540461500034, 70.72868002252068, 12.714123239076935, 61.09814687619725, 5.984689557108243, 53.80923640428431, 61.563832758064244, 62.4276073091722, 24.657532790895406, 29.23747438739117, 4.395661425861692, 19.722110029520454, 19.552554020039423, 20.466468094334687, 47.308390655155485, 26.864701453743418, 21.576946369825315, 55.110447725538805, 3.3091380091305997, 63.82346066940932, 24.16697294522279, 8.973005320678007, 31.70159091886506, 63.32464049283054, 61.49790402248017, 43.050662751666586, 64.24237395364021, 7.4586626880961955, 63.86593301163452, 74.89006566145041, 42.589250461909, 30.160267539359857, 49.74750939172935, 9.70432969708309, 13.597456140405347, 72.57760540758339]
# 88          24.494648         True                  False              False
# 89          42.268584        False                  False              False
# 90          31.788331         True                  False              False
# 91          77.877648        False                   True              False
#
#     is_big_galaxy  edited  double_model            QSO  azimuthal_angle
# 0           False   False         False  LBQS1435-0134        54.910136
# 1           False   False         False  LBQS1435-0134        84.430284
# 2            True   False         False  LBQS1435-0134        53.082844
# 3            True   False         False  LBQS1435-0134        53.354501
# 4            True   False         False  LBQS1435-0134        87.038570
# ..            ...     ...           ...            ...              ...
# 87           True   False         False     PG1206+459        30.188148
# 88           True   False         False     PG1206+459        49.800297
# 89          False   False         False     PG1206+459         9.695468
# 90           True   False         False     PG1206+459        14.082446
# 91           True   False         False     PG1206+459        72.630969
#
# [92 rows x 28 columns]

# %%
casbah.columns
# Out:
# Index(['level_0', 'index', 'gal_num', 'redshift', 'xcoord', 'xcoord_error',
#        'ycoord', 'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#        'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#        'axis_ratio', 'axis_ratio_error', 'position_angle',
#        'position_angle_error', 'reduced_chi_squared', 'inclination_angle',
#        'is_good_fit', 'shows_internal_struct', 'overlaps_w_object',
#        'is_big_galaxy', 'edited', 'double_model', 'QSO', 'azimuthal_angle'],
#       dtype='object')

# %%
del casbah['level_0']
del casbah['index']
cgm_initial.columns
# Out:
# Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#        'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#        'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#        'axis_ratio', 'axis_ratio_error', 'position_angle',
#        'position_angle_error', 'reduced_chi_squared', 'azimuthal_angle',
#        'inclination_angle', 'is_good_fit', 'shows_internal_struct',
#        'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO'],
#       dtype='object')

# %%
casbah.columns

# %%
print(len(casbah.columns)), print(len(cgm_initial.columns)), print(len(cgm_leftover.columns))
# Out:
# 26
# 26
# 26
# (None, None, None)

# %%
casbah.columns
# Out:
# Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#        'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#        'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#        'axis_ratio', 'axis_ratio_error', 'position_angle',
#        'position_angle_error', 'reduced_chi_squared', 'inclination_angle',
#        'is_good_fit', 'shows_internal_struct', 'overlaps_w_object',
#        'is_big_galaxy', 'edited', 'double_model', 'QSO', 'azimuthal_angle'],
#       dtype='object')

# %%
cgm_initial.columns
# Out:
# Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#        'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#        'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#        'axis_ratio', 'axis_ratio_error', 'position_angle',
#        'position_angle_error', 'reduced_chi_squared', 'azimuthal_angle',
#        'inclination_angle', 'is_good_fit', 'shows_internal_struct',
#        'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO'],
#       dtype='object')

# %%
cgm_leftover.columns
# Out:
# Index(['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
#        'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
#        'half_light_rad_error', 'sersic_index', 'sersic_index_error',
#        'axis_ratio', 'axis_ratio_error', 'position_angle',
#        'position_angle_error', 'reduced_chi_squared', 'azimuthal_angle',
#        'inclination_angle', 'is_good_fit', 'shows_internal_struct',
#        'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO'],
#       dtype='object')

# %% [markdown]
# ## making sure azimuthal angles are all in the same spot...

# %%
cgm_initial = cgm_initial[['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
       'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
       'half_light_rad_error', 'sersic_index', 'sersic_index_error',
       'axis_ratio', 'axis_ratio_error', 'position_angle',
       'position_angle_error', 'reduced_chi_squared',
       'inclination_angle', 'is_good_fit', 'shows_internal_struct',
       'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO', 'azimuthal_angle']]
cgm_initial
# Out:
#     gal_num  redshift   xcoord  xcoord_error   ycoord  ycoord_error  int_mag  \
# 0      1728  0.015210  1167.27          0.05   679.56          0.04    16.25
# 1      1729  0.071141  1663.52          0.00  1061.76          0.00    12.61
# 2      1731  0.114920   818.03          0.04  1547.88          0.01    14.50
# 3      1734  0.178165  1026.11          0.11  1258.15          0.05    16.12
# 4      1742  0.310258  1709.92          0.08   637.75          0.09    16.95
# ..      ...       ...      ...           ...      ...           ...      ...
# 13      852  0.400820  4116.03          0.01  2641.09          0.01    13.27
# 14      859  0.472508  2659.85          0.09  3034.45          0.10    15.43
# 15      860  0.472939  2737.14          0.08  3234.68          0.10    16.81
# 16      864  0.483531  3988.99          0.11  1844.67          0.13    16.58
# 17      878  0.644553  3825.32          0.08  2452.21          0.07    16.34
#
#     int_mag_error  half_light_rad  half_light_rad_error  ...  \
# 0            0.01            4.81                  0.11  ...
# 1            0.00            6.22                  0.03  ...
# 2            0.00           10.91                  0.05  ...
# 3            0.02            7.01                  0.22  ...
# 4            0.04            2.59                  0.22  ...
# ..            ...             ...                   ...  ...
# 13           0.01            9.90                  0.14  ...
# 14           0.01            8.79                  0.17  ...
# 15           0.04            2.89                  3.01  ...
# 16           0.07            5.55                  0.50  ...
# 17           0.02            5.09                  0.15  ...
#
#     reduced_chi_squared  inclination_angle  is_good_fit  \
# 0                 1.110          60.000000         True
# 1                 0.875          45.572996         True
# 2                 1.138          76.702928         True
# 3                 1.144          77.877648         True
# 4                 1.288          66.421822         True
# ..                  ...                ...          ...
# 13                0.811          42.268584         True
# 14                1.044          34.915206         True
# 15                1.102          67.666317         True
# 16                1.066          37.814489         True
# 17                1.072          63.896119         True
#
#     shows_internal_struct  overlaps_w_object  is_big_galaxy  edited  \
# 0                   False               True           True    True
# 1                    True              False           True    True
# 2                    True              False           True   False
# 3                   False              False           True   False
# 4                   False              False          False   False
# ..                    ...                ...            ...     ...
# 13                   True              False           True    True
# 14                  False              False           True   False
# 15                  False              False          False   False
# 16                  False              False           True   False
# 17                  False              False           True   False
#
#     double_model         QSO  azimuthal_angle
# 0          False  J1342-0053        76.049434
# 1          False  J1342-0053        48.017481
# 2          False  J1342-0053        87.433226
# 3          False  J1342-0053        65.266082
# 4          False  J1342-0053        88.692151
# ..           ...         ...              ...
# 13         False  J1016+4706        60.797316
# 14         False  J1016+4706        40.420450
# 15         False  J1016+4706        48.443678
# 16         False  J1016+4706        61.100673
# 17         False  J1016+4706        38.950732
#
# [247 rows x 26 columns]

# %%
cgm_leftover = cgm_leftover[['gal_num', 'redshift', 'xcoord', 'xcoord_error', 'ycoord',
       'ycoord_error', 'int_mag', 'int_mag_error', 'half_light_rad',
       'half_light_rad_error', 'sersic_index', 'sersic_index_error',
       'axis_ratio', 'axis_ratio_error', 'position_angle',
       'position_angle_error', 'reduced_chi_squared',
       'inclination_angle', 'is_good_fit', 'shows_internal_struct',
       'overlaps_w_object', 'is_big_galaxy', 'edited', 'double_model', 'QSO', 'azimuthal_angle']]
cgm_leftover
# Out:
#     gal_num  redshift   xcoord  xcoord_error   ycoord  ycoord_error  int_mag  \
# 0      1612  0.193030  2087.61          0.06  1970.73          0.09    12.88
# 1      1624  0.318496  1625.47          1.75  1236.02          1.53    15.64
# 0      1130  0.020901  1355.96          0.03  2227.53          0.03     8.82
# 0       497  0.092302  5029.98          0.10   926.77          0.08    15.60
# 1       502  0.125298  2020.51          0.04  2578.34          0.02    13.71
# ..      ...       ...      ...           ...      ...           ...      ...
# 2       627  0.228386  1389.90          0.02  1426.19          0.01    13.22
# 3       644  0.352952  1635.30          0.04  1221.06          0.04    15.84
# 0       949  0.074366  2743.58          0.12  2583.77          0.11    15.45
# 0       366  0.226509  4168.02          0.02   976.13          0.05    11.84
# 1       369  0.244314  3338.89          0.03  2008.97          0.02    13.27
#
#     int_mag_error  half_light_rad  half_light_rad_error  ...  \
# 0            0.01           15.20                  0.11  ...
# 1            0.37            4.27                 20.69  ...
# 0            0.19          207.26                 45.42  ...
# 0            0.04            8.43                  0.45  ...
# 1            0.01           11.55                  0.09  ...
# ..            ...             ...                   ...  ...
# 2            0.00            8.52                  0.06  ...
# 3            0.01            2.81                  0.08  ...
# 0            0.03           12.01                  0.38  ...
# 0            0.02           32.56                  0.57  ...
# 1            0.00           13.86                  0.06  ...
#
#     reduced_chi_squared  inclination_angle  is_good_fit  \
# 0                 4.705          52.410497        False
# 1               861.875          32.859880         True
# 0                 0.391          39.646111        False
# 0                 1.049          46.369891         True
# 1                 0.845          57.316361         True
# ..                  ...                ...          ...
# 2                 1.319          50.208181        False
# 3                 1.101          41.409622         True
# 0                 0.963          57.316361        False
# 0                 1.277          63.256316         True
# 1                 0.767          32.859880         True
#
#     shows_internal_struct  overlaps_w_object  is_big_galaxy  edited  \
# 0                    True               True           True   False
# 1                   False              False           True   False
# 0                    True              False           True   False
# 0                   False              False           True   False
# 1                   False              False           True   False
# ..                    ...                ...            ...     ...
# 2                    True              False           True   False
# 3                   False              False          False   False
# 0                   False               True           True    True
# 0                   False              False           True   False
# 1                    True              False           True   False
#
#     double_model         QSO  azimuthal_angle
# 0          False  J1233-0031        37.579913
# 1          False  J1233-0031        36.933422
# 0          False  J1059+2517        53.568683
# 0          False  J0935+0204        85.870873
# 1          False  J0935+0204        76.114832
# ..           ...         ...              ...
# 2          False  J0943+0531        58.229214
# 3          False  J0943+0531        85.468753
# 0          False  J1022+0132        60.893920
# 0          False  J0914+2823        23.596928
# 1          False  J0914+2823        71.057532
#
# [125 rows x 26 columns]

# %% [markdown]
# # Combining data frames from each subsection

# %%
combined_gals= pd.DataFrame()
frames= casbah,cgm_initial, cgm_leftover
for frame in frames:
    df= pd.concat([combined_gals, frame])
    combined_gals= df

# %%
combined_gals.to_csv('casbah_all_cgm_combined_ally.csv')
